# %%
from CC import CC

cc = CC("172.16.16.100", "root", "asd123!@")

cc.connect()
cc.run("ls -al")
cc.close()
# Out:
# 실행
# localhost.localdomain
#
# total 158504
# dr-xr-x---. 13 root root      4096 Nov 21 17:59 .
# dr-xr-xr-x. 21 root root      4096 Nov  4 11:15 ..
# -rw-------   1 root root       134 Nov 21 17:59 .Xauthority
# -rw-------   1 root root     11963 Nov 18 19:48 .bash_history
# -rw-r--r--.  1 root root        18 May 11  2022 .bash_logout
# -rw-r--r--.  1 root root       141 May 11  2022 .bash_profile
# -rw-r--r--.  1 root root       923 Oct 10 18:11 .bashrc
# drwxr-xr-x.  6 root root        68 Oct 20 11:24 .cache
# drwxr-xr-x.  3 root root        80 Oct 10 18:12 .conda
# -rw-r--r--.  1 root root        45 Oct 10 18:11 .condarc
# drwxr-xr-x   4 root root        37 Nov 18 15:34 .config
# -rw-r--r--.  1 root root       100 May 11  2022 .cshrc
# -rw-r--r--   1 root root        85 Oct 30 12:08 .gitconfig
# drwxr-xr-x   2 root root      4096 Oct 23 13:56 .ipynb_checkpoints
# drwxr-xr-x.  3 root root        29 Oct 13 16:41 .ipython
# drwxr-xr-x.  3 root root       101 Oct 28 11:43 .jupyter
# ...

# %%
from CC import CC
from DnsVhost import DnsVhost

cc =  CC("172.16.16.100", "root", "asd123!@")

cc.connect()
#cc.run("ls -al")
#cc.close()

dv = DnsVhost(cc) 
dv.test()
# Out:
# 실행
# DnsVhost init start
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7 #cc.run("ls -al")
#       8 #cc.close()
#      10 dv = DnsVhost(cc)
# ---> 11 dv.test()
#
# File /srv/jupyter/Rocky_class/DnsVhost.py:9, in DnsVhost.test(self)
#       8 def test(self):
# ----> 9     cc.run("touch test_py.txt")
#
# NameError: name 'cc' is not defined
