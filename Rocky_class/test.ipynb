# %%
from CC import CC

cc = CC("172.16.16.100", "root", "asd123!@")

cc.connect()
cc.run("ls -al")
cc.close()

# %%
from CC import CC
from DnsVhost import DnsVhost

cc =  CC("172.16.16.100", "root", "asd123!@")

cc.connect()
#cc.run("ls -al")
#cc.close()

dv = DnsVhost(cc) 
dv.test()
# Out:
# 실행
# DnsVhost init start
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7 #cc.run("ls -al")
#       8 #cc.close()
#      10 dv = DnsVhost(cc)
# ---> 11 dv.test()
#
# File /srv/jupyter/Rocky_class/DnsVhost.py:9, in DnsVhost.test(self)
#       8 def test(self):
# ----> 9     cc.run("touch test_py.txt")
#
# NameError: name 'cc' is not defined
