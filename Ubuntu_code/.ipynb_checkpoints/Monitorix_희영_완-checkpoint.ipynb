# %%
import paramiko
import subprocess

ip = "172.16.16.24"
user = "root"
pw = "asd123!@"
cmd = ""


def cc(cmd):
    cli = paramiko.SSHClient()
    cli.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    cli.connect(ip, username=user, password=pw, port=22)
    (stdin, stdout, stderr) = cli.exec_command(cmd,get_pty = True)
    out = stdout.read().decode()
    err = stderr.read().decode()
    cli.close()
    return out + err


def install_monitorix():
    print(cc("ls -l"))
    cmd = """
        apt update
        apt install apache2 -y
        apt install -y monitorix
    """

    print(cc(cmd))

    cc("systemctl stop ufw")
    print("=== 서비스 재시작 ===")
    cc("systemctl restart monitorix")

    print("=== 서비스 상태 확인 ===")
    print(cc("systemctl status monitorix"))

    print("http://ip:8080/monitorix로 접속하세요")

def go():
    install_monitorix()

go()
# Out:
# ---------------------------------------------------------------------------
# NoValidConnectionsError                   Traceback (most recent call last)
# Cell In[1], line 43
#      40 def go():
#      41     install_monitorix()
# ---> 43 go()
#
# Cell In[1], line 41, in go()
#      40 def go():
# ---> 41     install_monitorix()
#
# Cell In[1], line 22, in install_monitorix()
#      21 def install_monitorix():
# ---> 22     print(cc("ls -l"))
#      23     cmd = """
#      24         apt update
#      25         apt install apache2 -y
#      26         apt install -y monitorix
#      27     """
#      29     print(cc(cmd))
#
# Cell In[1], line 13, in cc(cmd)
#      11 cli = paramiko.SSHClient()
#      12 cli.set_missing_host_key_policy(paramiko.AutoAddPolicy())
# ---> 13 cli.connect(ip, username=user, password=pw, port=22)
#      14 (stdin, stdout, stderr) = cli.exec_command(cmd,get_pty = True)
#      15 out = stdout.read().decode()
#
# File ~/miniconda3/lib/python3.13/site-packages/paramiko/client.py:407, in SSHClient.connect(self, hostname, port, username, password, pkey, key_filename, timeout, allow_agent, look_for_keys, compress, sock, gss_auth, gss_kex, gss_deleg_creds, gss_host, banner_timeout, auth_timeout, channel_timeout, gss_trust_dns, passphrase, disabled_algorithms, transport_factory, auth_strategy)
#     401     # Make sure we explode usefully if no address family attempts
#     402     # succeeded. We've no way of knowing which error is the "right"
#     403     # one, so we construct a hybrid exception containing all the real
#     404     # ones, of a subclass that client code should still be watching for
#     405     # (socket.error)
#     406     if len(errors) == len(to_try):
# --> 407         raise NoValidConnectionsError(errors)
#     409 if transport_factory is None:
#     410     transport_factory = Transport
#
# NoValidConnectionsError: [Errno None] Unable to connect to port 22 on 172.16.16.25
