# %%
import pymysql

ip = "172.16.16.100"   
port = "3306"
id_ = "root"
pw = "asd123!@"

db_name = "test_db"
user_name = "test_user"

db = pymysql.connect(host=ip, user=id_, passwd=pw, charset='utf8')
cur = db.cursor()

# cur.execute(f"CREATE DATABASE {db_name}")
# cur.execute(f"CREATE USER '{user_name}'@'{s_ip}' IDENTIFIED BY '{pw}'")
# cur.execute(f"GRANT ALL PRIVILEGES ON {db_name}.* TO '{user_name}'@'{s_ip}'")
# cur.execute("FLUSH PRIVILEGES")

cur.close()
db.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 11
#       8 db_name = "test_db"
#       9 user_name = "test_user"
# ---> 11 db = pymysql.connect(host=d_ip, user=id_, passwd=pw, charset='utf8')
#      12 cur = db.cursor()
#      14 # cur.execute(f"CREATE DATABASE {db_name}")
#      15 # cur.execute(f"CREATE USER '{user_name}'@'{s_ip}' IDENTIFIED BY '{pw}'")
#      16 # cur.execute(f"GRANT ALL PRIVILEGES ON {db_name}.* TO '{user_name}'@'{s_ip}'")
#      17 # cur.execute("FLUSH PRIVILEGES")
#
# ...
